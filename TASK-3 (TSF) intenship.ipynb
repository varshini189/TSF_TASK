# %% [markdown]
# # The Sparks Foundation - Data Science & Business Analytics Internship
#
# ## - GRIPJULY21
#
# ## TASK 3: Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
#
#
# **AIM :** <b> As a business manager, try to find out the weak areas where you can
#           work to make more profit.
#
# **DatsetLink :** https://bit.ly/3i4rbWl
#
# **Language Used :** Pyhton 3
#
# **IDE :** Jupyter Notebook
#
# **type :** **EDA**
#
# **Author :** **BEENEEDI.VARSHINI**

# %% [markdown]
# ## Steps to be followed:
# ### * Importing the libraries
# ### * Reading the dataset
# ### * Data Preprocessing
# ### * EDA
# ### * Data Visualization

# %% [markdown]
# # Importing the libraries

# %%
#in this step we will import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#to ignore the warnings
import warnings as wg
wg.filterwarnings("ignore")

# %% [markdown]
# # Importing the DataSet

# %%
df = pd.read_csv("SampleSuperstore.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Data preprocessing

# %%
df.shape

# we can say that the dataset contaions 9977 rows and 13 columns.
# Out:
# (9977, 13)

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.info()

# to check the datatypes of the columns of the given dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
# Ship Mode       9994 non-null object
# Segment         9994 non-null object
# Country         9994 non-null object
# City            9994 non-null object
# State           9994 non-null object
# Postal Code     9994 non-null int64
# Region          9994 non-null object
# Category        9994 non-null object
# Sub-Category    9994 non-null object
# Sales           9994 non-null float64
# Quantity        9994 non-null int64
# Discount        9994 non-null float64
# Profit          9994 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.columns

# it will display various calumns names which were present in our dataset.
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.isnull().sum()

#to check whether our dataset contains null values.
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.duplicated().sum()

# it will give the number of duplicate rows present in our dataset.
# Out:
# 17

# %%
df.drop_duplicates(inplace=True)

# %%
#Removing the unnecessary columns

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
#visualising the data as whole part using the pair plot

import seaborn as sns
sns.pairplot(data)

# %%
#Finding the pair wise correlation between the columns and visualising using HeatMap

data.corr()
plt.figure(figsize=(10,5))
sns.heatmap(data.corr(),annot = True)
plt.show()

# %% [markdown]
# ## Visualising the Categories

# %%
plt.figure(figsize=(6,6))
textprops = {'fontsize':15}
plt.title("Category")
plt.pie(data['Category'].value_counts() , labels = data['Category'].value_counts().index,autopct='%1.1f%%',textprops = textprops)
plt.show()

# %%
plt.figure(figsize=(6,6))
textprops = {'fontsize':15}
plt.title("Sub-Category")
plt.pie(data['Sub-Category'].value_counts() , labels = data['Sub-Category'].value_counts().index,autopct='%1.1f%%',textprops = textprops)
plt.show()

# %%
plt.figure(figsize = (10,16))
data.groupby('Category')['Profit','Sales'].agg(['sum']).plot.bar() 
plt.ylabel('Profit')
plt.show()

# %%
plt.figure(figsize= (10,16))
data.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ## visualising the sales and profits of categories

# %% [markdown]
# #### computing the top categories in terms of sales from the first 100 observations
#
# #### computing the top categories in terms of profit from the first 100 observations

# %%
top_category_s = data.groupby("Category").Sales.sum().nlargest(n=100)
top_category_p = data.groupby("Category").Profit.sum().nlargest(n=100)

# plotting to see it visually

plt.style.use('seaborn')
top_category_s.plot(kind = 'bar',figsize = (10,5),fontsize = 14)
top_category_p.plot(kind = 'bar',figsize = (10,5),fontsize = 14,color='red')
plt.xlabel('Category',fontsize = 15)
plt.ylabel('Total Sales/Profits',fontsize = 15)
plt.title("Top Category Sales vs Profit",fontsize = 15)
plt.show()

# %% [markdown]
# ## visualising the Sub-Categories

# %%
# computing top sub-categories in terms of sales from first 100 observations
top_subcategory_s = data.groupby("Sub-Category").Sales.sum().nlargest(n = 100)
# computing top sub-categories in terms of profit from first 100 observations
top_subcategory_p = data.groupby("Sub-Category").Profit.sum().nlargest(n = 100)

# plotting to see it visually
plt.style.use('seaborn')
top_subcategory_s.plot(kind = 'bar',figsize = (10,5),fontsize = 14)
top_subcategory_p.plot(kind = 'bar',figsize = (10,5),fontsize = 14, color = 'red')
plt.xlabel('Sub-Category',fontsize = 15)
plt.ylabel('Total Sales/Profits',fontsize = 15)
plt.title("Top Sub-Category Sales vs Profit",fontsize = 15)
plt.show()

# %% [markdown]
# ### A more detailed view

# %%
plt.figure(figsize = (14,12))
statewise = data.groupby(["Sub-Category"])['Profit'].sum().nlargest(50)
statewise.plot.barh()
plt.show()

# %% [markdown]
# ##### The above graph clearly shows that Copiers and Phones have the highest sales and profit and tables has negative profit

# %% [markdown]
# ### Visualizing the Discount

# %%
plt.figure(figsize=(14,12))
sns.lineplot(data['Discount'],data['Profit'],data = data)

# %% [markdown]
# ### visualizing the Sales Vs Profits in Region wise

# %% [markdown]
# ##### Plotting the pie Chart on the regions

# %%
plt.figure(figsize=(6,6))
plt.title("Region")
plt.pie(data["Region"].value_counts(),labels=data["Region"].value_counts().index,autopct = '%1.1f%%')
plt.show()

# %%
plt.figure(figsize=(14,12))
data.groupby(['Region'])['Profit' , 'Sales'].agg(['sum']).plot.bar()
plt.ylabel("profit")
plt.show()

# %% [markdown]
# ### From the above Bar graph we can say that the west region has more profits and more sales compared to others regions

# %% [markdown]
# ## Visulalizing the Sales Vs Profits in diff states

# %%
# Computing the sales in different states from the  top 10 Observations

top_observation_s = data.groupby(["State"]).Sales.sum().nlargest(n = 10)

# Computing the profits in different states from the  top 10 Observations

top_observation_p = data.groupby(["State"]).Profit.sum().nlargest(n = 10)

plt.style.use("seaborn")

#plotting the Sales
 
top_observation_s.plot(kind = 'bar' , figsize =(10,5),fontsize = 14)

#plotting the Profits

top_observation_p.plot(kind = "bar",figsize = (10,5),fontsize =14 , color ='red')

plt.xlabel("States",fontsize = 15)
plt.ylabel("Total Profit/Sales",fontsize = 15)
plt.title('Sales Vs Profit in Diff States',fontsize = 15)
plt.show()

# %% [markdown]
# # checking the InterDependency of Sales,Profit,Discount

# %%
plt.style.use("seaborn")
data.plot(kind = "scatter",figsize = (10,5),x = "Sales" , y = "Profit" , c = "Discount" , s = 20 , fontsize = 15 , colormap = "viridis")
plt.show()

# %% [markdown]
# ### From the above graph we can say that if we give more Discounts - the sales increases but the profit decreases.

# %% [markdown]
# # Conclusion :
# ## The weak areas where one can work to make more profit are :
#
# ### 1. We have to  limit the sales on furniture and  should increase the more sales on both Technology and Office Supplies because the furniture has less profits.
#
# ### 2. considering the Sub-Categories the Tables giving loss ,so, we have to minimize the sales of Tables.
#
# ### 3. Increase the Sales more in East as we can see the Profit there.
#
# ### 4. We should concentrate more on  " California " and " NewYork " cities to makes more profits ,has they are showing more profits compared to other states
